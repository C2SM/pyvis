# %%
# IGNORE THIS CELL WHICH CUSTOMIZES LAYOUT AND STYLING OF THE NOTEBOOK !
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings = lambda *a, **kw: None

# %%
import xarray as xr
import numpy as np
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import psyplot.project as psy
psy.rcParams['auto_show'] = True
# %config InlineBackend.close_figures = False

# %%
#ds = xr.open_dataset("../../icon-vis/data/example_data/nc/my_exp1_atm_3d_ml_20180921T000000Z.nc")
ds = xr.open_dataset("../data.nc")
ds.ALNU.values = np.log10(ds.ALNU.values + 1)

# %%
# get data
#lon, lat, temp = ds.clon.values[:], ds.clat.values[:], ds.temp.values[1,1,:]

#ax = plt.axes(projection=ccrs.Robinson())

#ax.coastlines()

#ax.pcolormesh(lon,lat,temp, transform=ccrs.PlateCarree, shading="nearest" )
#ax.pcolormesh(ds.ncells.values[:], temp, transform=ccrs.PlateCarree, shading='nearest')

#ax.set_global()
#ax.set_extent([-1, 17, 42, 51], ccrs.PlateCarree())

# %%
# Checkout the formatoptions (https://psyplot.github.io/psy-maps/generated/psyplot.project.plot.mapplot.html)
# change the grid color to white, add a label to the colorbar, change the projection and cmap etc.
plot1 = ds.psy.plot.mapplot(
    name="ALNU",
    title="Alder Pollen in the Alps on 2020-02-15 20h",
    titlesize=15,
    grid_color="white",
    cticksize=8,
    clabel="Log. Pollen Concentrations [Pollen/m³]",
    grid_labelsize=8,
    projection='robin',
    cmap='RdBu_r')

# %%
#Checkout https://github.com/C2SM/iconarray
import iconarray

# %%
plot1 = ds.psy.plot.mapplot(
    name="ALNU",
    title="Alder Pollen in the Alps on 2020-02-15 20h",
    titlesize=15,
    grid_color="white",
    cticksize=8,
    clabel="Log. Pollen Concentrations [Pollen/m³]",
    grid_labelsize=8,
    projection='robin',
    cmap='RdBu_r')

# %%
plot1.update(lakes=False, borders=False, rivers=False)
